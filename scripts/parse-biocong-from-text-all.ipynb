# %% [markdown]
# We then parse the content of each file extracting the following information:
#
# 1. Name, e.g. RICHARD SHELBY
# 2. Party, e.g., Republican
# 3. location, e.g., Tuscaloosa, AL
# 4. born_in, e.g, Birmingham, AL
# 5. birthdate, e.g., May 6, 1934
# 6. education, e.g., "attended the public schools;  B.A., University of Alabama, 1957; LL.B., University of Alabama School of Law, 1963;"
# 7. professional, e.g., "attorney; admitted to the Alabama Bar in 1961 and commenced practice in  Tuscaloosa; member, Alabama State Senate, 1970-78; law clerk, Supreme Court of Alabama, 1961-62; city prosecutor, Tuscaloosa, 1963-71; U.S. Magistrate, Northern District of Alabama, 1966-70; Special Assistant  Attorney General, State of Alabama, 1969-71; chairman, Legislative
# Council of the Alabama Legislature, 1977-78; former president,
# Tuscaloosa County Mental Health Association; member, Alabama Code
# Revision Committee, 1971-75; member, Phi Alpha Delta legal fraternity,
# Tuscaloosa County; Alabama and American Bar Associations; First
# Presbyterian Church of Tuscaloosa; Exchange Club; American Judicature
# Society; Alabama Law Institute;"
# 8. married, e.g., "the former Annette Nevin in 1960"
# 9. children, e.g., "Richard C., Jr., and Claude Nevin"
# 10. committees, e.g., "chair, Appropriations; Banking, Housing, and Urban Affairs; Environment and  Public Works; Joint Committee on the Library; Rules and Administration;  elected to the 96th Congress on November 7, 1978; reelected to the three  succeeding Congresses; elected to the U.S. Senate on November 4, 1986; reelected to each succeeding Senate term."
# 11. URL, e.g., http://jones.senate.gov etc.
# 12. Filename, e.g., CDIR-2018-10-29-STATISTICALINFORMATION-2.htm

# %%
import re
import calendar
import requests
import pandas as pd
from glob import glob
import re

# %%
data = []
for fn in glob('../data/text/*.txt'):
    m = re.match('.*?(\d+)\.txt', fn)
    if m:
        cong = int(m.group(1))
    data.append({'congress': cong, 'textfile': fn})
data
# Out:
# [{'congress': 102, 'textfile': '../data/text/102.txt'},
#  {'congress': 98, 'textfile': '../data/text/98.txt'},
#  {'congress': 103, 'textfile': '../data/text/103.txt'},
#  {'congress': 104, 'textfile': '../data/text/104.txt'},
#  {'congress': 97, 'textfile': '../data/text/97.txt'},
#  {'congress': 100, 'textfile': '../data/text/100.txt'},
#  {'congress': 101, 'textfile': '../data/text/101.txt'},
#  {'congress': 99, 'textfile': '../data/text/99.txt'}]

# %%
df = pd.DataFrame(data)
df
# Out:
#    congress              textfile
# 0       102  ../data/text/102.txt
# 1        98   ../data/text/98.txt
# 2       103  ../data/text/103.txt
# 3       104  ../data/text/104.txt
# 4        97   ../data/text/97.txt
# 5       100  ../data/text/100.txt
# 6       101  ../data/text/101.txt
# 7        99   ../data/text/99.txt

# %%
df.sort_values('congress', inplace=True)
df
# Out:
#    congress              textfile
# 4        97   ../data/text/97.txt
# 1        98   ../data/text/98.txt
# 7        99   ../data/text/99.txt
# 5       100  ../data/text/100.txt
# 6       101  ../data/text/101.txt
# 0       102  ../data/text/102.txt
# 2       103  ../data/text/103.txt
# 3       104  ../data/text/104.txt

# %%
total = 0
bios = []
for i, r in df.iterrows():
    with open(r.textfile, encoding='latin-1') as f:
        text = f.read()
    count = 0
    for m in re.finditer('^(\s+[A-Z\s\,\.]{4,}.*)$', text, flags=re.M):
        t = m.group(1)
        for l in t.split('\n'):
            if len(l) > 50:
                if l.startswith('  ') and l[2] != ' ':
                    bios.append({'congress': r.congress, 'biography': l.strip()})
                    #print(l)
                    #print('-'*50)
                    count += 1
    print(r.congress, count)
    total += count
total
# Out:
# 97 526
# 98 523
# 99 530
# 100 535
# 101 538
# 102 531
# 103 531
# 104 453
# 4167

# %%
bdf = pd.DataFrame(bios)
bdf
# Out:
#       congress                                          biography
# 0           97  GEORGE HERBERT WALKER BUSH, Republican, of Hou...
# 1           97  HOWELL THOMAS HEFLIN, Democrat, of Tuscumbia, ...
# 2           97  JACK EDWARDS, Republican, of Mobile, Ala.; bor...
# 3           97  WILLIAM WUIS DICKINSON, Republican, of Montgom...
# 4           97  WILLIAM NICHOLS, Democrat, of Sylacauga, Ala.;...
# ...        ...                                                ...
# 4162       104  ENI F.H. FALEOMAVAEGA, Democrat, of Vailoatai ...
# 4163       104  ELEANOR HOLMES NORTON, Democrat, of Washington...
# 4164       104  ROBERT A. UNDERWOOD, Democrat, of Vona, GU; bo...
# 4165       104  CARLOS  ROMERO-BARCELO,  Democrat,  of San  Ju...
# 4166       104  VICTOR 0. FRAZER,  Independent,  of St. Thomas...
#
# [4167 rows x 2 columns]

# %%
df = df.join(bdf.set_index('congress'), on='congress')
df.reset_index(inplace=True, drop=True)
df
# Out:
#       congress              textfile  \
# 0           97   ../data/text/97.txt
# 1           97   ../data/text/97.txt
# 2           97   ../data/text/97.txt
# 3           97   ../data/text/97.txt
# 4           97   ../data/text/97.txt
# ...        ...                   ...
# 4162       104  ../data/text/104.txt
# 4163       104  ../data/text/104.txt
# 4164       104  ../data/text/104.txt
# 4165       104  ../data/text/104.txt
# 4166       104  ../data/text/104.txt
#
#                                               biography
# 0     GEORGE HERBERT WALKER BUSH, Republican, of Hou...
# 1     HOWELL THOMAS HEFLIN, Democrat, of Tuscumbia, ...
# 2     JACK EDWARDS, Republican, of Mobile, Ala.; bor...
# 3     WILLIAM WUIS DICKINSON, Republican, of Montgom...
# 4     WILLIAM NICHOLS, Democrat, of Sylacauga, Ala.;...
# ...                                                 ...
# 4162  ENI F.H. FALEOMAVAEGA, Democrat, of Vailoatai ...
# 4163  ELEANOR HOLMES NORTON, Democrat, of Washington...
# 4164  ROBERT A. UNDERWOOD, Democrat, of Vona, GU; bo...
# 4165  CARLOS  ROMERO-BARCELO,  Democrat,  of San  Ju...
# 4166  VICTOR 0. FRAZER,  Independent,  of St. Thomas...
#
# [4167 rows x 3 columns]

# %%
def extract_born_in(txt):
    months = [calendar.month_name[i] for i in range(1, 13)]
    txt = txt.strip().replace('in ', '')
    m = re.match('.*?((?:%s)\s+\d{,2},?\s+\d{,4})' % '|'.join(months), txt)
    if m:
        c = m.group(1)
        b = txt.replace(c, '').strip(', ')
    else:
        a = re.split('(%s)' % '|'.join(months), txt)
        b = a[0].strip(', ')
        if len(a) > 2:
            c = ''.join(a[-2:])
        else:
            c = None
    return b, c

# %%
def extract_key_value(key, b, idx):
    val_start = (idx + 1)
    try:
        val_end = idx + b[idx + 1:].index(':')
    except:
        val_end = len(b)
    value = ''.join(b[val_start:val_end])
    # FIXME:
    value = value.split('elected')[0]
    #print(' -', key.upper(), value)
    return value

# %%
def get_married_to(value):
    m = re.match('(?:married to\s|wife[\-,]|husband,?|spouse,|married,?)(.*?)[;,]', value)
    if m:
        married = m.group(1)
        if re.search('child', married):
            #print(married)
            return None
        else:
            #print(married)
            return married
    else:
        #print(value)
        return None

# %%
bios = []
keys = dict()
for i, row in df.iterrows():
    data = {}
    if row.biography:
        bio = row.biography.replace('\n', '').strip()
        m = re.match('(.*?(?:, Jr\.|, DVM|, P\.E\.|, IV|, D\.V\.M\.|, M\.D\.)?)[;,]\s+(.*?(?:Democrat|Republican|Independent|Party).*?)[;,]?(?:\sof\s)?.*', bio)
        if m:
            data['name'] = m.group(1)
            data['party'] = re.split(',|;', m.group(2))[-1]
            pass
        else:
            print('WARN: Cannot parse name and party:', i, bio[:60])
            pass
        m = re.match('.*?(?:.*?(?:Democrat|Republican|Independent|Party).*?[;, ])?(?:\sof\s)?(.*?)(?:born|education|graduate|professional|attorney|b\.).*', bio, re.I)
        if m:
            data['location'] = m.group(1).replace(';', '')
            pass
        else:
            print('WARN: Cannot parse location:', i, bio[:60])
            pass
        m = re.match('.*?\s+born(.*?)(?:;|,\s+education)', bio, re.I)
        if m:
            # parse born_in and birthdate
            born_in, birthdate = extract_born_in(m.group(1))
            data['born_in'] = born_in
            data['birthdate'] = birthdate
            pass
        else:
            print('WARN: Cannot parse born:', i, bio[20:100])
            pass
        """
        education, e.g., "attended the public schools; B.A., University of Alabama, 1957; LL.B., University of Alabama School of Law, 1963;"
        professional, e.g., "attorney; admitted to the Alabama Bar in 1961 and commenced practice in Tuscaloosa; member, Alabama State Senate, 1970-78; law clerk, Supreme Court of Alabama, 1961-62; city prosecutor, Tuscaloosa, 1963-71; U.S. Magistrate, Northern District of Alabama, 1966-70; Special Assistant Attorney General, State of Alabama, 1969-71; chairman, Legislative Council of the Alabama Legislature, 1977-78; former president, Tuscaloosa County Mental Health Association; member, Alabama Code Revision Committee, 1971-75; member, Phi Alpha Delta legal fraternity, Tuscaloosa County; Alabama and American Bar Associations; First Presbyterian Church of Tuscaloosa; Exchange Club; American Judicature Society; Alabama Law Institute;"
        married, e.g., "the former Annette Nevin in 1960"
        children, e.g., "Richard C., Jr., and Claude Nevin"
        committees, e.g., "chair, Appropriations; Banking, Housing, and Urban Affairs; Environment and Public Works; Joint Committee on the Library; Rules and Administration; elected to the 96th Congress on November 7, 1978; reelected to the three succeeding Congresses; elected to the U.S. Senate on November 4, 1986; reelected to each succeeding Senate term."
        URL, e.g., http://jones.senate.gov etc.
        """
        a = re.split('(\. |,|;|:)', bio)
        b = [c.strip() for c in a]
        #print(b)
        for idx in [j for j, x in enumerate(b) if x == ":"]:
            key = b[idx - 1]
            if key not in keys:
                keys[key] = 1
            else:
                keys[key] += 1
            value = extract_key_value(key, b, idx)
            if key in ['education']:
                data[key] = value
            elif re.search('profession', key):
                data['professional'] = value
            elif key in ['married']:
                data[key] = value
            elif re.search('^child|\schild|son|daughter', key):
                data['children'] = value
            elif re.search('committee', key):
                data['committees'] = value
            elif re.search('family', key):
                data['married'] = get_married_to(value)
    #print('-'* 50)
    bios.append(data)
    #if i > 50:
    #    break
# Out:
# WARN: Cannot parse name and party: 17 ELDON RUDD, Re_P-11blican, of Scottsdale, Ariz.; born in Cam
# WARN: Cannot parse name and party: 41 CHARLES PASHAYAN, Ja., Re blican, of Fresno, Calif.; born in
# WARN: Cannot parse name and party: 129 HENRY J. HYDE, RepubliC8;fi, of Bensenville, Ill.; born in C
# WARN: Cannot parse location: 131 DAN ROSTENKOWSKI, Democrat, of Chicago,  Ill.; educated  in
# WARN: Cannot parse born: 131 mocrat, of Chicago,  Ill.; educated  in  St.  John's  Mili­ tary Academy and Loy
# WARN: Cannot parse born: 170 UM, Republican, of Wichita, Kans.; bom in Topeka, Kans., July 29, 1932, the daug
# WARN: Cannot parse location: 210 EDWARD P. BOLAND, Democrat, of Springfield, Mass.; elected t
# WARN: Cannot parse born: 210 mocrat, of Springfield, Mass.; elected to 83d and ree­ lected to 84th, 85th, 86t
# WARN: Cannot parse name and party: 251 THAD COCHRAN,  Reeublican, of Jackson, Miss.; born in Pontot
# WARN: Cannot parse name and party: 364 BOB McEWEN, ReJ?ublican, of Hillsboro, Ohio; born in Hillsbo
# WARN: Cannot parse born: 394 mocrat, of Portland, Oreg.; bor.a in Wichita, Kans., May 3, 1949; attended Garla
# WARN: Cannot parse location: 395 JIM WEAVER, Democrat, of Eugene, Oreg.; elected to the 94th
# WARN: Cannot parse born: 395 , of Eugene, Oreg.; elected to the 94th Congress, Novem­ ber 5, 1974; reelected
# WARN: Cannot parse name and party: 397 ARLEN SPECTER. Republican, of Philadelphia, Pa.; born in Wic
# WARN: Cannot parse born: 409 crat, of Johnstown, Pa.; graduated, Ramsey High School, Mount Pleasant, Pa.; Kis
# WARN: Cannot parse born: 425 RMAIN, Democrat, of Woonsocket, R.l.; Ph. B., Provi­ dence College; LL. B., Bost
# WARN: Cannot parse location: 433 KEN HOLLAND, Democrat, of Gaffney, S.C.; married November  2
# WARN: Cannot parse born: 433 t, of Gaffney, S.C.; married November  24, 1976, to Diane L. Martin  of  Loris,
# WARN: Cannot parse born: 448 t, of Memphis, Tenn.; bom in Memphis, May 20, 1945; son of Newton W. and Vera Fo
# WARN: Cannot parse born: 584 emocrat,  of San Pedro, Calif.; bom  in  Hawthorne, Calif., February 21, 1913; B
# WARN: Cannot parse location: 663 CARDISS COLLINS, Democrat, of Chicago, Ill.; bom in St. Loui
# WARN: Cannot parse born: 663 ocrat, of Chicago, Ill.; bom in St. Louis, Mo., September 24, 1931; moved to Det
# WARN: Cannot parse location: 664 DAN ROSTENKOWSKI, Democrat, of Chicago, Ill.; educated in St
# WARN: Cannot parse born: 664 mocrat, of Chicago, Ill.; educated in St. John's Mili­ tary Academy and Loyola U
# WARN: Cannot parse name and party: 670 TOM CORCORAN, P.ublican, of Ottawa, Ill.; born in Ottawa, Il
# WARN: Cannot parse name and party: 686 DANNY LEE BURTON, Recfi: lican, of Indianapolis, Ind.; born
# WARN: Cannot parse name and party: 717 ROB;ERT L. LIVIN<;tSTON, JR., ReJ>ublican, of Ne':"' ,OrlE;8
# WARN: Cannot parse location: 742 EDWARD P. BOLAND, Democrat, of Springfield, Mass.; elected t
# WARN: Cannot parse born: 742 mocrat, of Springfield, Mass.; elected to 83d and re­ elected to 84th, 85th, 86t
# WARN: Cannot parse name and party: 762 DONALD J. ALBOSTA, Domocrat, of St. Charles, Mich.; born in
# WARN: Cannot parse location: 826 JOSEPH GEORGE MINISH, Democrat, of West Orange, N.J.; World
# WARN: Cannot parse born: 826 , Democrat, of West Orange, N.J.; World War II veteran; member, Knights of Colum
# WARN: Cannot parse name and party: 846 CHARLES ELLIS SCHUMER. Democrat, of Brooklyn, N.Y.; born in
# WARN: Cannot parse location: 917 JIM WEAVER, Democrat, of Eugene, Oreg.; elected to the 94th
# WARN: Cannot parse born: 917 , of Eugene, Oreg.; elected to the 94th Congress, Novem­ ber 5, 1974; reelected
# WARN: Cannot parse born: 931 crat, of Johnstown, Pa.; graduated, Ramsey High School, Mount Pleasant, Pa.; Kis
# WARN: Cannot parse born: 944 RMAIN, Democrat, of Woonsocket, R.I.; Ph. B., Provi­ dence College; LL.B., Bosto
# WARN: Cannot parse location: 1189 DAN ROSTENKOWSKI, Democrat, of Chicago, IL; educated in St.
# WARN: Cannot parse born: 1189 mocrat, of Chicago, IL; educated in St. John's Military Academy and Loyola Unive
# WARN: Cannot parse location: 1265 EDWARD P. BOLAND, Democrat, of Springfield, MA; elected to 8
# WARN: Cannot parse born: 1265 mocrat, of Springfield, MA; elected to 83d and re­ elected to 84th, 85th, 86th,
# WARN: Cannot parse born: 1273 ocrat, of Cohasset, MA; bom in Mineola, NY, May 12, 1937; attended public school
# WARN: Cannot parse born: 1274 emocrat, of Dorchester, MA; bom in Dorchester, MA, March 2, 1946; attended priva
# WARN: Cannot parse born: 1412 ocrat, of Bismarck, ND; .born in Dickinson, ND, May 14, 1942; graduated, Regent
# WARN: Cannot parse name and party: 1444 BOB PACKWOOD, Rep_ublican, of Portland, OR; born in Portland
# WARN: Cannot parse location: 1448 JIM  WEAVER, Democrat, of Eugene, OR; elected to the 94th Co
# WARN: Cannot parse born: 1448 t, of Eugene, OR; elected to the 94th Congress, November 5, 1974; reelected to e
# WARN: Cannot parse born: 1462 crat, of Johnstown, PA; graduated, Ramsey High School, Mount Pleasant, PA; Kiski
# WARN: Cannot parse born: 1465 ER, Republican, of Coopersburg, PA; bom in New York, NY, October 21, 1940; Sc.D.
# WARN: Cannot parse born: 1476 RMAIN, Democrat, of Woonsocket, RI; Ph.B., Provi­ dence College; LL.B., Boston U
# WARN: Cannot parse name and party: 1521 THOMAS D. (TOM) DELAY, Reiblican, of Sugar Land, TX; born in
# WARN: Cannot parse born: 1546 blican, of Olympia, WA; ,born January 8, 1928, Chicago, Il..; graduated high sch
# WARN: Cannot parse born: 1607 mocrat, of Occidental, CA; on July 28, 1946; attended Capitol Page High School,
# WARN: Cannot parse name and party: 1656 HANK BROWN, Refublican, of Greeley, CO, born in Denver, CO,
# WARN: Cannot parse location: 1718 DAN ROSTENKOWSKI, Democrat, of Chicago, IL; educated in St.
# WARN: Cannot parse born: 1718 mocrat, of Chicago, IL; educated in St. John's Military Academy and Loyola Unive
# WARN: Cannot parse name and party: 1789 BEVERLY B. BYRON, De ocrat, of Frederick; MD; born in Baltim
# WARN: Cannot parse location: 1795 EDWARD P. BOLAND, Democrat, of Springfield, MA; elected to 8
# WARN: Cannot parse born: 1795 mocrat, of Springfield, MA; elected to 83d and reelected to each succeeding Cong
# WARN: Cannot parse name and party: 1878 .A.A.M.A.); 1969 Annual State Golden Medal Award of the Gard
# WARN: Cannot parse location: 1878 .A.A.M.A.); 1969 Annual State Golden Medal Award of the Gard
# WARN: Cannot parse born: 1878 ual State Golden Medal Award of the Garden Clubs of  New rsey for conservation e
# WARN: Cannot parse born: 1993 crat, of Johnstown, PA; graduated, Ramsey High School, Mount Pleasant, PA; Kiski
# WARN: Cannot parse born: 2007 RMAIN, Democrat, of Woonsocket, RI; Ph.B., Providence College; LL.B., Brown Univ
# WARN: Cannot parse name and party: 2038 JOE LINUS BARTON Republican, of Ennis, TX; born in Waco, TX,
# WARN: Cannot parse name and party: 2109 FOFO l.F. SUNIA,. Democrat, of Pago Pago, American Samoa; bo
# WARN: Cannot parse born: 2142 mocrat, of Occidental, CA; on July 28, 1946; attended Capitol Page High School,
# WARN: Cannot parse born: 2183 epublican, of  Lomita, CA; bom in Coronado, CA, on June 21, 1947; graduated Palo
# WARN: Cannot parse location: 2256 DAN ROSTENKOWSKI, Democrat, of Chicago, IL; educated in St.
# WARN: Cannot parse born: 2256 mocrat, of Chicago, IL; educated in St. John's Military Academy and Loyola Unive
# WARN: Cannot parse born: 2446 an, of New York, NY; l?<>m in New  York City, October 16, 1929; B.A., Harvard Co
# WARN: Cannot parse born: 2531 crat, of Johnstown, PA; graduated, Ramsey High School, Mount Pleasant, PA; Kiski
# WARN: Cannot parse born: 2598 n, Salt Lake City, UT; _born in Richfield, UT, October 12, 1932; son of the late
# WARN: Cannot parse name and party: 2621 AL SWI FT , Democr at, of Bellingham, WA; born in Taco ma, W
# WARN: Cannot parse born: 2647 A,  Democrat, of Pago Pago, AS, graduate of Kahuku High School, Hawaii, 1962; B.
# WARN: Cannot parse name and party: 2680 FRANK RIGGS, Rupublican, of Santa Rosa, CA; attended Saint M
# WARN: Cannot parse born: 2680 can, of Santa Rosa, CA; attended Saint Mary's College, Moraga, CA; attended Univ
# WARN: Cannot parse born: 2694 crat, of Ceres, CA; attended Modesto Junior College and Cal State University, St
# WARN: Cannot parse name and party: 2745 CONNIE MACK, Repubhcan, of Cape Coral, FL; born in Philadelp
# WARN: Cannot parse location: 2794 DAN ROSTENKOWSKI, Democrat, of Chicago, IL; educated in St.
# WARN: Cannot parse born: 2794 mocrat, of Chicago, IL; educated in St. John's Military Academy and Loyola Unive
# WARN: Cannot parse name and party: 2885 FREDERICK. S. UPTON, llepublican, of St. Joseph, MI; born in
# WARN: Cannot parse born: 3062 crat, of Johnstown, PA; graduated, Ramsey High School, Mount Pleasant, PA; Kiski
# WARN: Cannot parse born: 3106 an, of Ennis, TX; bom in Waco, TX, tember 15, 1949; attended Travis Elementary S
# WARN: Cannot parse name and party: 3153 SID MORRISON, Re_publican, of Zillah, WA; born in Yakima, WA
# WARN: Cannot parse born: 3178 A, Democrat, of Pago Pago, AS, graduate of Kahuku High School, Hawaii, 1962; B.A
# WARN: Cannot parse name and party: 3243 Los ANGELES CoUNTY; cities of Culver  City, ,..,. Angeles Ci
# WARN: Cannot parse location: 3243 Los ANGELES CoUNTY; cities of Culver  City, ,..,. Angeles Ci
# WARN: Cannot parse born: 3243 cities of Culver  City, ,..,. Angeles City  (part), communities  or  CffllshaW,
# WARN: Cannot parse name and party: 3261 BOB FILNER.,  t,	of San Diego, CA;  born,  !Jer 4, 1942, in
# WARN: Cannot parse name and party: 3313 JOHN LINDER. Republican, of Atlanta, GA; born on September 9
# WARN: Cannot parse location: 3335 DAN ROSTENKOWSKI, Democrat, of Chicago, IL; educated at St.
# WARN: Cannot parse born: 3335 mocrat, of Chicago, IL; educated at St. John's Military Academy and Loyola Unive
# WARN: Cannot parse name and party: 3340 JOHN EDWARD POR.TER. Republican, of Wilmette, IL; born in Ev
# WARN: Cannot parse born: 3373 at, of Topeka, KS; boin August 4, 1948, in community of Good Intent, Atchison Co
# WARN: Cannot parse name and party: 3426 NICK SMITH, Repubhcan, of Addison, Ml; born in Addison, on N
# WARN: Cannot parse name and party: 3434 BARBARA-ROSE COLLINS. Democrat, of Detroit, Ml; born in Detr
# WARN: Cannot parse born: 3592 crat, of Johnstown, PA; graduated, Ramsey High School, Mount Pleasant, PA; Kiski
# WARN: Cannot parse born: 3629 , Republican, of Dallas, TX, raised in La Marque, TX; graduate of the University
# WARN: Cannot parse born: 3636 can, of Houston, TX; min Houston, TX, arch 2J,19_28; graduated from St. Thomas H
# WARN: Cannot parse born: 3649 emocrat, of San Antonio, TX; born in San Antonio, May 3, 1916, son of Leonides (
# WARN: Cannot parse born: 3709 A, Democrat, of Vailoatai, Pago Pago,  AS,  graduate of Kahuku High School, Hawa
# WARN: Cannot parse name and party: 3714 AL GORE. Democrat. of Carthage, 1N; born Much 31, 1948; grad
# WARN: Cannot parse name and party: 3723 MATT SALMON. Republican. of Mesa. AZ; born in Salt Lake City
# WARN: Cannot parse name and party: 3726 JIM KOLBE. Republican, of Tucson, AZ; born in Evanston,  IL,
# WARN: Cannot parse born: 4127 Republican, of Newport News, VA; bom in Elizlbcdl City, NC, August 7, 1928; educ
# WARN: Cannot parse born: 4140 ican, of Langley. WA;  bom  in Marysville,  WA,  November  30. 1927; B.A., Pacif
# WARN: Cannot parse name and party: 4142 NORMAN D. DICKS , Dcmocnit. of Bremerton, WA; born in Bremer
# WARN: Cannot parse born: 4144 lican, of Bellewe, WA; bom July 29, 1941 in Seattle, WA; B.A., Stanford Universi
# WARN: Cannot parse name and party: 4153 MARK  W. NEUMANN.  Republican,  of Janesville, WI; born on F
# WARN: Cannot parse born: 4162 A, Democrat, of Vailoatai Pago Pago, AS, graduate of Kahuku High School, Hawaii,
# WARN: Cannot parse born: 4163 N, Democrat, of Washington, DC; bom in Wuhington. DC, June 13, 1937; attended pu

# %%
bdf = pd.DataFrame(bios)
bdf
# Out:
#                             name        party  \
# 0     GEORGE HERBERT WALKER BUSH   Republican
# 1           HOWELL THOMAS HEFLIN     Democrat
# 2                   JACK EDWARDS   Republican
# 3         WILLIAM WUIS DICKINSON   Republican
# 4                WILLIAM NICHOLS     Democrat
# ...                          ...          ...
# 4162       ENI F.H. FALEOMAVAEGA     Democrat
# 4163       ELEANOR HOLMES NORTON     Democrat
# 4164         ROBERT A. UNDERWOOD     Democrat
# 4165      CARLOS  ROMERO-BARCELO     Democrat
# 4166            VICTOR 0. FRAZER  Independent
#
#                                                location  \
# 0     Houston, Tex. 43d Vice President  of  the  Uni...
# 1                                      Tuscumbia, Ala.
# 2                                         Mobile, Ala.
# 3                                     Montgomery, Ala.
# 4                                      Sylacauga, Ala.
# ...                                                 ...
# 4162                          Vailoatai Pago Pago, AS,
# 4163  Washington, DC bom in Wuhington. DC, June 13, ...
# 4164                                          Vona, GU
# 4165                         of San  Juan,  Pueno Rico
# 4166                  of St. Thomas,  Virgin  Islands
#
#                                                 born_in          birthdate  \
# 0                                        Milton,  Mass.     June  12, 1924
# 1     _21 son of Reverend MarvR. Hefl and  Louise  D...        June 19, 19
# 2                Birmingham, Ala., Sep­ tember 20, 1928               None
# 3                                       Ope­ lika, Ala.       June 5, 1925
# 4                    on a small farm near Becker, Miss.   October 16, 1918
# ...                                                 ...                ...
# 4162                                                NaN                NaN
# 4163                                                NaN                NaN
# 4164                                     Tamuning, Guam      July 13, 1948
# 4165                         on   San Juan, Puerto Rico  September 4, 1932
# 4166                   Charlotte Amalie, St. Thomas, VI       May 24, 1943
#
#                                        children professional committees  \
# 0           George,Jeb,Neil,Marvin,and Dorothy;          NaN        NaN
# 1                                           NaN          NaN        NaN
# 2                                           NaN          NaN        NaN
# 3                                           NaN          NaN        NaN
# 4                  M_emorie,Margaret,and Flynt;          NaN        NaN
# ...                                         ...          ...        ...
# 4162                                        NaN          NaN        NaN
# 4163                                        NaN          NaN        NaN
# 4164                                 Sophia,Ro­          NaN        NaN
# 4165  Car­ los,Andres,Juan Carlos,and  Melinda;          NaN        NaN
# 4166                                        NaN          NaN        NaN
#
#      education married
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 4162       NaN     NaN
# 4163       NaN     NaN
# 4164       NaN     NaN
# 4165       NaN     NaN
# 4166       NaN     NaN
#
# [4167 rows x 10 columns]

# %%
bdf.party.unique()
# Out:
# array(['Republican', 'Democrat', ' Republican', nan, ' Democrat',
#        'Independent', 'Conservative-Republican', ' Independent',
#        ' elected Republican', '  Democrat',
#        ' is chairman of the Democrat', ' Assistant Senate Republican',
#        ' National Republican', '·Democrat', ' California Republican',
#        '  Republican', ' ranking Republican',
#        ' member: Nevada Federation of Republican',
#        ' chairman of the National Republican',
#        ' Outagamie County Young Republican'], dtype=object)

# %%
df[df.index.isin(bdf[bdf.party.isnull()].index)]
# Out:
#       congress              textfile  \
# 17          97   ../data/text/97.txt
# 41          97   ../data/text/97.txt
# 129         97   ../data/text/97.txt
# 251         97   ../data/text/97.txt
# 364         97   ../data/text/97.txt
# ...        ...                   ...
# 4110       104  ../data/text/104.txt
# 4120       104  ../data/text/104.txt
# 4125       104  ../data/text/104.txt
# 4142       104  ../data/text/104.txt
# 4153       104  ../data/text/104.txt
#
#                                               biography
# 17    ELDON RUDD, Re_P-11blican, of Scottsdale, Ariz...
# 41    CHARLES PASHAYAN, Ja., Re blican, of Fresno, C...
# 129   HENRY J. HYDE, RepubliC8;fi, of Bensenville, I...
# 251   THAD COCHRAN,  Reeublican, of Jackson, Miss.; ...
# 364   BOB McEWEN, ReJ?ublican, of Hillsboro, Ohio; b...
# ...                                                 ...
# 4110  LARRY COMBEST. Republican, of Lubbock, TX; bor...
# 4120  ORRIN G. HATCH. Republican, of Salt Lake City,...
# 4125  JOHN W. WARNER. Republican, of Alexandria, VA;...
# 4142  NORMAN D. DICKS , Dcmocnit. of Bremerton, WA; ...
# 4153  MARK  W. NEUMANN.  Republican,  of Janesville,...
#
# [66 rows x 3 columns]

# %%
import operator

for k in sorted(keys.items(), key=operator.itemgetter(1), reverse=True):
    print(k)
# Out:
# ('member', 2129)
# ('three children', 561)
# ('two children', 558)
# ('four children', 286)
# ('five children', 154)
# ('awards', 101)
# ('two daughters', 80)
# ('children', 57)
# ('former member', 54)
# ('chairman', 53)
# ('committee assignments', 49)
# ('two sons', 44)
# ('elected', 43)
# ('committees', 41)
# ('six children', 40)
# ('three daughters', 38)
# ('honorary degrees', 35)
# ('', 34)
# ('three sons', 34)
# ('one child', 33)
# ('author', 27)
# ('recipient', 25)
# ('three chil\xad dren', 24)
# ('board member', 23)
# ('two chil\xad dren', 23)
# ('past president', 22)
# ('seven children', 21)
# ('attended', 18)
# ('trustee', 15)
# ('two  children', 15)
# ('honors', 15)
# ('profession', 14)
# ('subcommittees', 14)
# ('board of directors', 13)
# ('eight children', 13)
# ('four chil\xad dren', 13)
# ('married', 13)
# ('Senate committees', 12)
# ('honors and awards', 12)
# ('president', 11)
# ('served', 11)
# ('served as', 10)
# ('one daughter', 10)
# ('served on', 9)
# ('director', 9)
# ('six grandchildren', 9)
# ('military awards', 9)
# ('four sons', 9)
# ('committee member', 9)
# ('four daughters', 8)
# ('"Alternative Dispute Resoultion in the Federal Government', 2)
# ('civic ac\xad tivities', 2)
# ('two grown children', 2)
# ('two children from previous marriage', 2)
# ('admitted to the bar', 2)
# ('n', 2)
# ('the children of their blended family are', 2)
# ('1969-77', 2)
# ('father of four sons with the late Lula Hancock Drake Spence', 2)
# ('president of Board of Supervisors', 2)
# ('Ways and Means', 2)
# ('member of the following Senate committees', 2)
# ('awarded honorary degrees', 2)
# ('one  child', 2)
# ('other career experience', 2)
# ('mother of two children', 2)
# ('1965', 2)
# ('three children (including two sons by previous marriage)', 2)
# ('one child by former marriage', 2)
# ('29 years', 2)
# ('I', 2)
# ('"U.S.A.', 2)
# ('Stanford t.', 2)
# ('committee', 2)
# ('_', 2)
# ('Democ', 2)
# ('1961', 2)
# ('1964', 2)
# ('lawy-er', 1)
# ('University of .Alabama and University of North Alabama', 1)
# ('Parker Fertili7.er Co.', 1)
# ('1948', 1)
# ('past  chairman', 1)
# ('reelected to each su..', 1)
# ('parents', 1)
# ('attended Occidental College and California In\xad stitute of Technology  under  Navy V-5  Pilot  Program', 1)
# ('SIX children', 1)
# ('married Sallie Hansen of Santa Monica', 1)
# ('and as Assistant U.S', 1)
# ('Cit', 1)
# ('elected to Colorado General Assembly', 1)
# ('received awards from', 1)
# ('of Colorado Sbi°', 1)
# ('born in C', 1)
# ('they have four sons and three daughters', 1)
# ('Commissioner of', 1)
# ('Combat Infantry', 1)
# ('Dist hed Eu', 1)
# ('author of four books', 1)
# ('-former chairman  of the  board of directors', 1)
# ('clubs', 1)
# ('former Sunda', 1)
# ('two  daughters', 1)
# ('chosen by President Eisenhower to head the Republican Committee on Pro\xad grams and Progress', 1)
# ('Belleville 1', 1)
# ('19', 1)
# ('board of directors member', 1)
# ('Our Lady of Pompeii Grammar', 1)
# ('admitted t.o the  bar of the 11', 1)
# ("August '1", 1)
# ('Ill', 1)
# ('Outstanc', 1)
# ('1941-45', 1)
# ('honor degrees', 1)
# ('3 Y', 1)
# ("Governor's advisory", 1)
# ('married  Patti Crocker  of  Baton  Rouge  and  is  the  father of  three  children', 1)
# ('graduated', 1)
# ("July 'l", 1)
# ('and  College of  the Holy eross....', 1)
# ('born April ?', 1)
# ('19?', 1)
# ('attended Birmin I', 1)
# ('three clilldren', 1)
# ('subcommattee on c', 1)
# ('of Trenl', 1)
# ('graduated Chisholm Hu!', 1)
# ('elected to the Mississippi House of Representatives when 21 years of age and served one session', 1)
# ('a hotel-casino in Carson Cit>', 1)
# ('children (previous marriage)', 1)
# ('Chilton Memorial Hosl', 1)
# ('_ recipient', 1)
# ('"Harvard Hates America', 1)
# ('Supreme Court', 1)
# ('honorary ees', 1)
# ('LL.J', 1)
# ("born Janu\xad ary 'l", 1)
# ('born in Philadel\xad i', 1)
# ('three chil n', 1)
# ('mem r', 1)
# ('four  daughters', 1)
# ('A', 1)
# ('served on  the boards of', 1)
# ('hui', 1)
# ('att.ended Okla\xad homa Stat.e University', 1)
# ('three of their own', 1)
# ('two nieces and  a nephew', 1)
# ('city attorne', 1)
# ('past resident', 1)
# ('1962-78', 1)
# ('three children  by  previous marriage', 1)
# ('two da h\xad ters', 1)
# ('and Journal of F..c', 1)
# ('Committee on Ways and Means', 1)
# ('past  president', 1)
# ('chief legislative counsel to U', 1)
# ('admitted to the State Bar of Te', 1)
# ('four  sons', 1)
# ('Na")\' and served \'l', 1)
# ('NORMAN Dl', 1)
# ('"Revenue Sharing', 1)
# ('"To Save Our Cities', 1)
# ('deacon  and lay pr', 1)
# ('RON 011', 1)
# ('reelected to sw', 1)
# ('six chil n', 1)
# ('Army Reserves and Air', 1)
# ('reelected to the United i', 1)
# ('served two terms', 1)
# ('founder', 1)
# ('98th Congress', 1)
# ('r', 1)
# ('executive com', 1)
# ('five adult -children', 1)
# ('they have five sons and three daughters', 1)
# ('attended the public e', 1)
# ('Communit', 1)
# ('December 2', 1)
# ('September 2', 1)
# ('192', 1)
# ('niversity of Illi', 1)
# ('consistently endorsed by both the Chicago Sun-Times and the Cbu', 1)
# ('National Newsc', 1)
# ('active3in', 1)
# ('received the degree of Bachelor of Philosophy from the Univei', 1)
# ('civics and history at HarJM', 1)
# ('one boJ"', 1)
# ('hono degrees', 1)
# ('member  of or  affiliated  with', 1)
# ('Recfi', 1)
# ('public  service  activities', 1)
# ('Y', 1)
# ('degi', 1)
# ("of Ne'", 1)
# ('L.l', 1)
# ('Covington &', 1)
# ('ranki!}B', 1)
# ('three  daughters', 1)
# ('1975-77 member', 1)
# ('Intergovernmental Relations Committee of the N.C', 1)
# ('University  of  Missouri', 1)
# ('Jr', 1)
# ('current member', 1)
# ('awards and -tions', 1)
# ('planning board attorn', 1)
# ('"tted to practice', 1)
# ('direct.or', 1)
# ('reelected to each succeeding Congress', 1)
# ('of Centerport', 1)
# ('member·', 1)
# ('priv', 1)
# ('_ N.Y', 1)
# ('served on the  boards of', 1)
# ("born April 'l", 1)
# ('attended Okla\xad homa State University', 1)
# ('member of several congressional caucuses including', 1)
# ('served as chief counsel to the Texas', 1)
# ('former consultant', 1)
# ('Com\xad mittee on Ways and Means', 1)
# ('del te', 1)
# ('honors and  awards', 1)
# ('Duke 1/nivi', 1)
# ('"The F.qual Rights Amendment Extension', 1)
# ('West Virginians for Fair and', 1)
# ('entered United States Army as a private in February', 1)
# ('married t', 1)
# ('high.school', 1)
# ('deacon and lay p_i', 1)
# ('Selma to Montgomery Mar', 1)
# ('El(', 1)
# ('99th Congress', 1)
# ('employed  by  the  Chrysler  Coq', 1)
# ('council  liaison  to California  Unified  Port  District', 1)
# ('96th and 97th Con\xad gresses', 1)
# ('98th Con\xad gress', 1)
# ('grad\xad uated', 1)
# ('honorary doctorates', 1)
# ('Honorary Doctorate of Law', 1)
# ('former  member', 1)
# ('former chairman of the board  of  directors', 1)
# ('ad\xad mitted', 1)
# ('author of Rulemak\xad ers of the House (Urbana', 1)
# ('married to the former', 1)
# ('1942 aqd 1943', 1)
# ('JOHN E', 1)
# ('AFL-', 1)
# ('Ken Gray &', 1)
# ('LaLumiere  High Schc', 1)
# ('uat', 1)
# ('Jack', 1)
# ('Foreign Affairs Commit\xad t.ee', 1)
# ('Oak Ric', 1)
# ('hl', 1)
# ('past preeident', 1)
# ('fpur children', 1)
# ('ME', 1)
# ('former ru', 1)
# ("July '1", 1)
# ('chan2ed party affiliation to Democrat on February 2', 1)
# ('Rec', 1)
# ('f', 1)
# ('George Bush for Presicfent Committee', 1)
# ('Mid\xad land Area Chamber of Commerce', 1)
# ('admitt.ed to the following bars', 1)
# ('campaign commit\xad tees', 1)
# ('reelected to each 1', 1)
# ("November 'l", 1)
# ('six grandchil\xad dren', 1)
# ('a hotel-<', 1)
# ('board of directors of such public service organim\xad tions', 1)
# ('admitted to prac\xad tice', 1)
# ('Gadomski two children', 1)
# ('eight chil\xad dren', 1)
# ('y', 1)
# ('two sons (former  marriage)', 1)
# ('postgradu\xad ate courses', 1)
# ('past or present include', 1)
# ('six  children', 1)
# ('two ·children', 1)
# ('attended Oklaho\xad ma State University', 1)
# ('past member', 1)
# ('busi\xad ness', 1)
# ('mili\xad tary service', 1)
# ('po\xad litical', 1)
# ('graduat.e study', 1)
# ('· member', 1)
# ('Transportation Subcommittee', 1)
# ('District of Columbia Subcommittee', 1)
# ('executive board member of the Central South Carolina Council of the Bo B<', 1)
# ('Senat.e', 1)
# ('member of several congressional caucusea including', 1)
# ('school honon', 1)
# ('current membenhips in\xad clude', 1)
# ('B.S', 1)
# ('awards and orga\xad nizations', 1)
# ('May', 1)
# ('appoint\xad ed', 1)
# ('Trustee', 1)
# ('tax accountant for Arthur Anderson  &', 1)
# ('New Britain Bank &', 1)
# ('reelected to each su<', 1)
# ('former chairman of  the board of directors', 1)
# ('" Resolution of which served as chairman "Tht Mars Proj«I', 1)
# ('/D7\'mtys Beyond lht Cold Wiir" (NY', 1)
# ('honorar.y degrees', 1)
# ('Foreign Affairs Committee', 1)
# ('House Permanent Select Committee an Intelligence former member', 1)
# ('· awards', 1)
# ('public serv\xad ice activities', 1)
# ('}', 1)
# ('Senate Novemb', 1)
# ('and pro\xad fessional organizations', 1)
# ('married Patti Crocker of Baton Rouge and is the father of three children', 1)
# ('appointed  to', 1)
# ('George Bush for President Committee', 1)
# ('Midland Area Chamber of Com\xad merce', 1)
# ('admitted to the following  bars', 1)
# ('executive di\xad rector', 1)
# ('1976--82', 1)
# ("'former member", 1)
# ('subcommittees on', 1)
# ('teacher and acting principal in Wall Township school system 195z..', 1)
# ('steering committees of', 1)
# ('honorary doc\xad toral degrees', 1)
# ('House Republican Leadership', 1)
# ("C'", 1)
# ('two grand\xad children', 1)
# ('awards  and  honors', 1)
# ('Military serv\xad ice', 1)
# ('admitts', 1)
# ('ta', 1)
# ('Arms Control and Foreign Policy', 1)
# ('citations and awards', 1)
# ('"The Equal Rights  Amendment  Extension', 1)
# ('serves on Subcommittees on', 1)
# ('serves on Sub\xad committees on', 1)
# ('professional and fraternal affili\xad ations', 1)
# ('and two  daughters', 1)
# ('awards and organizations', 1)
# ('Mount J', 1)
# ('(>Ut president', 1)
# ('put  chairman', 1)
# ('Recip\xad ient', 1)
# ('C', 1)
# ('1959', 1)
# ('and Juns Doctor deJJ', 1)
# ('Select Committee to lw', 1)
# ('"To Establish the United States Academy of Peace', 1)
# ('of which served as chairman "The Mars Project· Journeys Beyond the Cold War" (NY', 1)
# ('Congressional Caucuses', 1)
# ('henorary degr ees', 1)
# ('member of or atlUiated with', 1)
# ('practiced law as a trial attorney in the law firm of Livinaston & Powers', 1)
# ('George Bush for President Commit\xad tee', 1)
# ('Midland Area Chamber of Commerce', 1)
# ('Committee', 1)
# ('awards received', 1)
# ('reelected to eacl', 1)
# ('Honon and awards', 1)
# ('father of four sons with the late Lula Hancock Brake Spence', 1)
# ('past chairm', 1)
# ('and two daughters', 1)
# ('[NOTE', 1)
# ('· AZ', 1)
# ('son', 1)
# ('two    children', 1)
# ('Hawthorne Chamber of Commerce', 1)
# ('serves on Subcommittees', 1)
# ('council liaison to California Unified Port Diatrict', 1)
# ('Commiuion of the Califomian1', 1)
# ('author of six books', 1)
# ('married to the former Joan Louise Fo', 1)
# ('two childrm', 1)
# ('two cbildrcn', 1)
# ('two/children', 1)
# ('February', 1)
# ('193', 1)
# ('Briar QitT Col\xad lege Board of Trustec', 1)
# ('KS', 1)
# ('Southern Kentucky', 1)
# ('"One', 1)
# ('for the 6-yeBI', 1)
# ('1988', 1)
# ('· three children', 1)
# ('1962-63 serving as c', 1)
# ('attcndc', 1)
# ('umucccasful ca', 1)
# ('widowed mother of two children', 1)
# ('1966', 1)
# ('(business administration and a.', 1)
# ('six chil\xad dren', 1)
# ('Louia University School of Commerce', 1)
# ('graduated Las Vegas High School', 1)
# ('Amer\xad k', 1)
# ('I><', 1)
# ('past president and board member', 1)
# ('sons', 1)
# ('1986', 1)
# ('A.F.&', 1)
# ('Space and Technology Subcom\xad mittees', 1)
# ('Public Works and Transportation Subcommittees', 1)
# ('Added awards', 1)
# ('1961-69', 1)
# ('Committee assignments', 1)
# ('196', 1)
# ('partner in law firm of Stanford &', 1)
# ('honon', 1)
# ('proreaaion', 1)
# ('to\xad gether they have five children', 1)
# ('Marin County Board of Supervisors', 1)
# ('1982 to 98th Congress', 1)
# ('re\xad elected to the 99th-102d Congresses', 1)
# ('Chair', 1)
# ('chairpenon', 1)
# ('honorary member', 1)
# ('special c', 1)
# ('Nov', 1)
# ('co\xad founder', 1)
# ('1980-86', 1)
# ('OK', 1)
# ('they have three sons', 1)
# ('Recipient', 1)
# ('past member of Board of Directors', 1)
# ("Lee County ._'i", 1)
# ('e', 1)
# ('three grandchildren', 1)
# ('recognitions and awards', 1)
# ('Aariculture', 1)
# ('"Freedom\'s Champion', 1)
# ('committee memberships', 1)
# ('1984-86', 1)
# ('1988-92', 1)
# ('1 91', 1)
# ('1991-present', 1)
# ('comtnittee assignments', 1)
# ('publisl', 1)
# ('at-large member', 1)
# ('KY', 1)
# ('LA', 1)
# ("ommission o'", 1)
# ('1990', 1)
# ('two daughtcra', 1)
# ('1962', 1)
# ('1955-63 and currendy holds rank of Lieutenant-Colonel in Nevada  National Guard', 1)
# ('member on committees', 1)
# ('Fi\xad nance and Urban Affairs', 1)
# ('Judiciary', 1)
# ('Foreign  Affairs', 1)
# ('appointed chairman of the Congressional Black Caucm Higher &', 1)
# ('honorably discharged with rank of staff 5t', 1)
# ('mber', 1)
# ('and "The Congressional Experience', 1)
# ('The Klamath Tribe', 1)
# ('television journalist', 1)
# ('Professional  career', 1)
# ('honorary Degrees', 1)
# ('Arms Control and For\xad eign Policy', 1)
# ('Board of Visitors', 1)
# ('Star Wars.', 1)
# ('member of Tenneaee House of Representatives', 1)
# ('received', 1)
# ('1971', 1)
# ("''The Equal Rights Amendment Extension", 1)
# ("''The Role of Congress in Sentencing", 1)
# ('Appropriations Committee', 1)
# ('Judiciary Committee', 1)
# ('chairperson', 1)
# ('elected to tl', 1)
# ('four duldren', 1)
# ('AL on May', 1)
# ('Alabama and Amer- ."\'-\'I', 1)
# ('1.', 1)
# ("Natioaal Cbildren's Ad\xad YOCW", 1)
# ("AmericlD Bar Auociation's Nalional Lelli Relourc", 1)
# ('awards 111d bonon', 1)
# ('1991-95', 1)
# ('commillees', 1)
# ('subcommiuces', 1)
# ('AZ', 1)
# ('served deputy din', 1)
# ('two dauf!t.crs', 1)
# ('pastJresiJent', 1)
# ('pasl chairman', 1)
# ('private law pm', 1)
# ('1984-89', 1)
# ('and Stephanie Thornton', 1)
# ('1970- 78', 1)
# ('committee  assignments', 1)
# ("'", 1)
# ('married to the former Joanne Aw', 1)
# ('studied at the Monicrey lnstitule of Inter-', 1)
# ('president )', 1)
# ("'ti", 1)
# ("1992 to the 103d Congress.\t't", 1)
# ('1941  in i', 1)
# ('1992 Envi-', 1)
# ("The '", 1)
# ('National Organization  for  ..i', 1)
# ('1990  Legislator', 1)
# ('STI', 1)
# ('Unwed Power', 1)
# ('Congressional Ethics', 1)
# ('M', 1)
# ('balanced the city budget and elimmated a $2.5 million deficit without imposing new r', 1)
# ('and secured federal assistance .', 1)
# ('was only elected official ever to receive the Florence Sabin Award for contributions to rural health care and received several awards from the United Veterans Commission of Colorado', 1)
# ('ranking member', 1)
# ('hon\xad orary degrees', 1)
# ("co-vice chairman for NGA's Tasli", 1)
# ('PETT', 1)
# ('1985-92', 1)
# ('mem ber', 1)
# ('George Washington t.', 1)
# ('three chil\xad drtn', 1)
# ('Volun- 1', 1)
# ('board of    ·t', 1)
# ('two childml', 1)
# ('1tu', 1)
# ('cla', 1)
# ('Aorida- .', 1)
# ('-', 1)
# ('Bilingual   PrivllC \x95', 1)
# ('\'.!".', 1)
# ('Amanda   Michelle', 1)
# ('\x95', 1)
# ('born in West Palm Beach oo l)c._', 1)
# ('Virginia Military Insti-"·\'', 1)
# ('-.i', 1)
# ("Governor's Special Task  Foox '", 1)
# ('...-', 1)
# ('United Way of Palu', 1)
# ('com\xad mittee assignments', 1)
# ('Cad', 1)
# ('attended_ M ls L', 1)
# ('two cbildml', 1)
# ('re\xad dected to each suc', 1)
# ('OH', 1)
# ('organization  member', 1)
# ('four cbildrea', 1)
# ('attc', 1)
# ('four ch!ldrcn', 1)
# ('Rcsoun', 1)
# ('Big Brothers and Sisters of Greater Pittsburgh', 1)
# ('ranking 1 member', 1)
# ('caucus organization memberships', 1)
# ('two cluldrcn', 1)
# ('Fam\xad ily', 1)
# ('Govenunc', 1)
# ('father of four sons with the late Lula Han\xad cock Drue Spence', 1)
# ('president of Soucb Carolina Auoc', 1)
# ('dRc children', 1)
# ('member of Tc', 1)
# ('anessee House of Representatives', 1)
# ('duce children', 1)
# ('111tbor of several boob including', 1)
# ('tbrcc sons', 1)
# ('c', 1)
# ('re\xad elected to each succeeding Congn', 1)
# ('American Institute of An', 1)
# ('and  Subcommittee  on Basic Rescarc', 1)
# ('mem- It ber', 1)
# ('House Select Commit\x95 11', 1)
# ('two cbildren', 1)
# ('Chamber of Com\xad mm', 1)
# ('oac child', 1)
# ('Hispanic Heritage Confcn', 1)
# ('officers c', 1)
# ('ertific', 1)
# ('1935 in W1JJ', 1)
# ('honorary Doctor of Laws', 1)
# ('"The Equal  Rights  Amendment  Extension', 1)
# ('"Alternative Dispute Resoultion  in the Federal Government', 1)
# ('"The Role of Congress in Sentencing', 1)
# ('admitted to the District of Columbia bar 1979', 1)
# ('admitted to practice befon', 1)
# ('Nutrition and Forestry', 1)
# ('Ap\xad propriations Committee', 1)
# ('Judiciary COIDID.lttee', 1)
# ('two c', 1)
# ('bildren', 1)
# ('committee usignmcnts', 1)
# ('three claughlers', 1)
# ('businessmm', 1)
# ('elcc', 1)
# ('two cbildraa', 1)
# ('VA', 1)
# ('elecled', 1)
# ('services', 1)
# ('Rolling Bay Presbyterian Cbun', 1)
# ('House Commen', 1)
# ('private law pnc1icc', 1)
# ('immc', 1)
# ('diatt', 1)
# ('appoinced to', 1)
# ('presidential appoinl.CC', 1)
# ('el«', 1)
# ('news reporu', 1)
# ('two IOIIS', 1)
# ('subsequently t1', 1)
# ('past memberships', 1)
# ('1987-92', 1)
# ('1993-94', 1)
# ('Republican activities', 1)
# ('banking', 1)
# ('New York', 1)
# ('attorney', 1)
# ('Virgin Islands Water and Power Authority', 1)
# ('work', 1)
# ('admitted to bar', 1)
# ('two chiJdrcn', 1)

# %%
cdf = df.join(bdf)
cdf
# Out:
#       congress              textfile  \
# 0           97   ../data/text/97.txt
# 1           97   ../data/text/97.txt
# 2           97   ../data/text/97.txt
# 3           97   ../data/text/97.txt
# 4           97   ../data/text/97.txt
# ...        ...                   ...
# 4162       104  ../data/text/104.txt
# 4163       104  ../data/text/104.txt
# 4164       104  ../data/text/104.txt
# 4165       104  ../data/text/104.txt
# 4166       104  ../data/text/104.txt
#
#                                               biography  \
# 0     GEORGE HERBERT WALKER BUSH, Republican, of Hou...
# 1     HOWELL THOMAS HEFLIN, Democrat, of Tuscumbia, ...
# 2     JACK EDWARDS, Republican, of Mobile, Ala.; bor...
# 3     WILLIAM WUIS DICKINSON, Republican, of Montgom...
# 4     WILLIAM NICHOLS, Democrat, of Sylacauga, Ala.;...
# ...                                                 ...
# 4162  ENI F.H. FALEOMAVAEGA, Democrat, of Vailoatai ...
# 4163  ELEANOR HOLMES NORTON, Democrat, of Washington...
# 4164  ROBERT A. UNDERWOOD, Democrat, of Vona, GU; bo...
# 4165  CARLOS  ROMERO-BARCELO,  Democrat,  of San  Ju...
# 4166  VICTOR 0. FRAZER,  Independent,  of St. Thomas...
#
#                             name        party  \
# 0     GEORGE HERBERT WALKER BUSH   Republican
# 1           HOWELL THOMAS HEFLIN     Democrat
# 2                   JACK EDWARDS   Republican
# 3         WILLIAM WUIS DICKINSON   Republican
# 4                WILLIAM NICHOLS     Democrat
# ...                          ...          ...
# 4162       ENI F.H. FALEOMAVAEGA     Democrat
# 4163       ELEANOR HOLMES NORTON     Democrat
# 4164         ROBERT A. UNDERWOOD     Democrat
# 4165      CARLOS  ROMERO-BARCELO     Democrat
# 4166            VICTOR 0. FRAZER  Independent
#
#                                                location  \
# 0     Houston, Tex. 43d Vice President  of  the  Uni...
# 1                                      Tuscumbia, Ala.
# 2                                         Mobile, Ala.
# 3                                     Montgomery, Ala.
# 4                                      Sylacauga, Ala.
# ...                                                 ...
# 4162                          Vailoatai Pago Pago, AS,
# 4163  Washington, DC bom in Wuhington. DC, June 13, ...
# 4164                                          Vona, GU
# 4165                         of San  Juan,  Pueno Rico
# 4166                  of St. Thomas,  Virgin  Islands
#
#                                                 born_in          birthdate  \
# 0                                        Milton,  Mass.     June  12, 1924
# 1     _21 son of Reverend MarvR. Hefl and  Louise  D...        June 19, 19
# 2                Birmingham, Ala., Sep­ tember 20, 1928               None
# 3                                       Ope­ lika, Ala.       June 5, 1925
# 4                    on a small farm near Becker, Miss.   October 16, 1918
# ...                                                 ...                ...
# 4162                                                NaN                NaN
# 4163                                                NaN                NaN
# 4164                                     Tamuning, Guam      July 13, 1948
# 4165                         on   San Juan, Puerto Rico  September 4, 1932
# 4166                   Charlotte Amalie, St. Thomas, VI       May 24, 1943
#
#                                        children professional committees  \
# 0           George,Jeb,Neil,Marvin,and Dorothy;          NaN        NaN
# 1                                           NaN          NaN        NaN
# 2                                           NaN          NaN        NaN
# 3                                           NaN          NaN        NaN
# 4                  M_emorie,Margaret,and Flynt;          NaN        NaN
# ...                                         ...          ...        ...
# 4162                                        NaN          NaN        NaN
# 4163                                        NaN          NaN        NaN
# 4164                                 Sophia,Ro­          NaN        NaN
# 4165  Car­ los,Andres,Juan Carlos,and  Melinda;          NaN        NaN
# 4166                                        NaN          NaN        NaN
#
#      education married
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 4162       NaN     NaN
# 4163       NaN     NaN
# 4164       NaN     NaN
# 4165       NaN     NaN
# 4166       NaN     NaN
#
# [4167 rows x 13 columns]

# %%
cdf.to_csv('../data/biocong-text-all-parsed.csv', index=False)
